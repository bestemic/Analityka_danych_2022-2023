# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# > https://www.kaggle.com/datasets/shivachandel/kc-house-data

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
df = pd.read_csv("kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### Comment
# During the analysis of new data, displaying the first few rows allows to become familiar with the values and think about what to do with them.

# %%
#b) 
print(df.columns)
house_categorical_df = ['id', 'date', 'waterfront', 'view', 'condition', 'grade', 'zipcode']
house_numerical_df = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above',
                      'sqft_basement', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'yr_built', 'yr_renovated']
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ### Comment
# **Numerical variables** <br>
# The values of these variables are able to determine the quantities that we can measure. What is more using these kinds of variables, we can observe a relationship between the values.
#
# **Categorical variables** <br>
# The values of these variables take values from a specific limited set. What is more, using these types of variables, we can perform a qualitative analysis of data, as well as group data into categories and groups.
#
# Some variables are difficult to unambiguously assign whether they are numeric or categorical. In our dataset, such non-identifiable variables are *bedrooms*, *bathrooms*, *floors*, *grade*, *yr_built* ,*yr_renovated*. For this variables we can categorize the data but also count basic statistics.

# %%
#c)
df[house_numerical_df].describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    sqft_above  sqft_basement           lat          long  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       1.494309   1788.390691     291.509045     47.560053   -122.213896
# ...

# %% [markdown]
# ### Comment
# We can notice that *count* isn't meaningful statistic. The most significant and useful statistic turns out to be the *mean*. Looking at the mean for each column, we see that on average a house has 3 bedrooms and 2 bathrooms and costs 540 thousand.
#
# A useful value that describe function returns is also the maximum and minimum of a given column. Thanks to this, we can easily find out that the cheapest house cost 75 thousand and the most expensive 7.7. For our dataset, max also revealed that there may be houses that do not have a natural number of floors.

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
plt.figure(figsize=(10, 8))
plt.ticklabel_format(axis="y", style='plain')
plt.xlabel("sqft_living")
plt.ylabel("price")
plt.scatter(df.sqft_living, df.price)

# %% [markdown]
# ### Comment
# In the chart, we can read that there are more houses that are small and at the same time cheap, than houses that are expensive and with a large living area.

# %%
#b)
plt.figure(figsize=(10, 8))
plt.ticklabel_format(axis="y", style='plain')
plt.xlabel("grade")
plt.ylabel("price")
plt.scatter(df.grade, df.price)

# %% [markdown]
# ### Comment
# It is most evident in the chart that as the home's rating rises, its price goes up. This is understandable because houses with better construction are more durable and safer.

# %%
plt.figure(figsize=(10, 8))
plt.ticklabel_format(axis="y", style='plain')
plt.xlabel("condition")
plt.ylabel("price")
plt.scatter(df.condition, df.price)

# %% [markdown]
# ### Comment
# The price to condition ratio shows that the most expensive houses do not have the best condition, but the condition rated at 3 and 4 points.

# %%
plt.figure(figsize=(10, 5))
plt.ticklabel_format(axis="y", style='plain')
plt.xlabel("long")
plt.ylabel("price")
plt.scatter(df.long, df.price)
plt.show()

plt.figure(figsize=(10, 5))
plt.ticklabel_format(axis="y", style='plain')
plt.xlabel("lat")
plt.ylabel("price")
plt.scatter(df.lat, df.price)

# %% [markdown]
# ### Comment
# From both charts we can read that the most expensive houses are located more to the northwest of the studied area.

# %%
#c)
plt.figure(figsize=(10, 8))
plt.ticklabel_format(axis="y", style='plain')
plt.xlabel("zipcode")
plt.ylabel("price")
plt.scatter(df.zipcode, df.price)

# %% [markdown]
# ### Comment
# From the chart, we can read that prices are different between areas of the zipcode. Houses in some neighborhoods are more expensive than houses in others.

# %%
#Your code:
plt.figure(figsize=(16, 10))
plt.xlabel("longtitude")
plt.ylabel("latitide")
plt.scatter(df.long, df.lat, c=df.grade)
plt.colorbar()
plt.grid()

# %% [markdown]
# ### Comment
# The graph shows us the geographic grid of King Country areas with marked points representing houses. The brighter the point, the better the house rating. The best rated apartments are located in 47.5 - 47.7 latitude and -122.3 - -122.0 longitude.
#
# An additional curiosity are empty areas that relate to water bodies, parks or even airport.

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
grouped_df = df[['price', 'grade']].groupby('grade')['price'].apply(list)
plt.figure(figsize=(10, 8))
plt.ticklabel_format(axis="y", style='plain')
plt.xlabel("grade")
plt.ylabel("price")
plt.boxplot(grouped_df, flierprops=dict(markeredgecolor='blue', markerfacecolor='blue', marker='o'));

# %% [markdown]
# ### Comment
# Observing the graph, we can see that the median increases with the increase in the grade and it is not a linear increase. We also do not have as many outliers for the lowest and highest grades than for grades 5-11. The size between the first and third quantiles also increases as the rating increases.
#
# Comparing to diagram 2b we can see that the shape is similar, in places where in 2b we have crowded information, on the box plot we see "boxes" which inform us that this is where most of the data is. The remaining values are the same as the outliers.

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic

figure, _ = mosaic(df,['bedrooms','floors']);
figure.set_size_inches(10, 8)
figure.get_axes()[0].set_xlabel('bedrooms')
figure.get_axes()[0].set_ylabel('floors')
# Out:
# Text(0, 0.5, 'floors')

# %% [markdown]
# ### Comment
# Mosaic plots help show relationships and give a visual way to compare groups. We see that houses with one floor and 3 bedrooms are the most popular.

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
condition = lambda df: (df['bedrooms']==3) & (df['bathrooms'] == 2) & (df['floors'] == 2)
apartments = df.loc[condition] 
apartments[house_numerical_df].describe()
# Out:
#               price  bedrooms  bathrooms  sqft_living       sqft_lot  floors  \
# count  1.540000e+02     154.0      154.0   154.000000     154.000000   154.0
# mean   5.144986e+05       3.0        2.0  1850.279221   23678.948052     2.0
# std    2.497661e+05       0.0        0.0   547.585413   83324.024708     0.0
# min    2.090000e+05       3.0        2.0  1020.000000     700.000000     2.0
# 25%    3.769750e+05       3.0        2.0  1452.500000    3414.750000     2.0
# 50%    4.640000e+05       3.0        2.0  1700.000000    5868.500000     2.0
# 75%    5.894625e+05       3.0        2.0  2127.500000   10800.250000     2.0
# max    1.755000e+06       3.0        2.0  3650.000000  843309.000000     2.0
#
#         sqft_above  sqft_basement         lat        long  sqft_living15  \
# count   154.000000     154.000000  154.000000  154.000000     154.000000
# mean   1717.422078     132.857143   47.567376 -122.247091    1802.337662
# ...

# %% [markdown]
# ### Comment
# The average price of houses that meet this condition is about 514.5 thausond. All houses with this condition was build before 2015 and after 1900. Also we can notice that only 154 houses meet above condition.

# %%
#b)
plt.figure(figsize=(10, 8))
plt.ticklabel_format(axis="y", style='plain')
plt.xlabel("grade")
plt.ylabel("price")
plt.scatter(df.grade, df.price)
plt.scatter(apartments.grade, apartments.price, color='yellow', edgecolors='black', s=100)

# %% [markdown]
# ### Comment
# We can observe that homes that meet the above specifications are low-price (mostly less than one million) homes with an average grade.

# %%
#c)
apartments = apartments.copy()
apartments['price_to_sqrt_ratio'] = apartments['price'] / apartments['sqft_living']
apartments.sort_values('price_to_sqrt_ratio').head().loc[:, apartments.columns != 'price_to_sqrt_ratio']
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9704   7452500565  20140829T000000  260000.0         3        2.0
# 11258  7937600262  20140710T000000  379900.0         3        2.0
# 19880  3832050860  20150319T000000  210000.0         3        2.0
# 16014  5104450440  20141113T000000  252500.0         3        2.0
# 20906  3355400242  20141028T000000  274900.0         3        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9704          2710      5000     2.0           0     0  ...      6
# 11258         3110     44967     2.0           0     0  ...      9
# 19880         1580      4961     2.0           0     0  ...      7
# 16014         1810     10684     2.0           0     0  ...      8
# 20906         1936      6612     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 9704         2710              0      1951             0    98126  47.5188
# ...

# %% [markdown]
# ### Comment
# From the results, we can see that the best house has a price of 260,000 and a living area of 2,710 square meters. From the results, we can see that the best house has a price of 260,000 and a living area of 2,710 square meters.
